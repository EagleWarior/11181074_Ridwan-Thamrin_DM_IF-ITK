# %%
from google.colab import drive
drive.mount(‘/content/gdrive’)
# Out:
#   File "<ipython-input-2-03f774f3e4a3>", line 2
#     drive.mount(‘/content/gdrive’)
#                 ^
# SyntaxError: invalid character in identifier
